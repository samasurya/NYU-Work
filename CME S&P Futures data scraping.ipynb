# %%
import datamine.io as dm
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import style
style.use('fivethirtyeight')
# %matplotlib inline

# %%
myDatamine = dm.DatamineCon(username='api_NYUEcon', password='e@3tq7jM&4eaEY4Q@9G7qt39', path='./data/')

# %%
myDatamine.get_catalog(dataset= "TICK", limit = 22500)
# Out:
# get_catalog: retrieving TICK, limit 22500
# get_catalog: 22500-record limit reached
# get_catalog: 22500 records downloaded, 0 duplicates, 22500 saved

# %%
myDatamine.data_catalog.popitem()
# Out:
# ('19891106-TICK_xcme_sp_fut_0-rth',
#  {'dataset': 'TICK',
#   'yyyymmdd': '19891106',
#   'url': 'https://datamine.cmegroup.com/cme/api/v1/download?fid=19891106-TICK_xcme_sp_fut_0-rth',
#   'fid': '19891106-TICK_xcme_sp_fut_0-rth',
#   'orderid': '33513',
#   'exchangecode': 'xcme',
#   'productcode': 'sp',
#   'checksum': 'd6350819026ea22e7481056b54219330',
#   'size': 18437,
#   'expiration': '2021-10-29',
#   's3url': 'cmegroup-prod-us-east-1-datamine/timeandsales/19891106/xcme/fut/rth/sp/xcme-tick-sp-fut-19891106-r-00105.gz',
#   'is_regular_access': True})

# %%
dataCatalogDF = pd.DataFrame.from_dict(myDatamine.data_catalog,).T
dataCatalogDF.head()
# Out:
#                                 dataset  yyyymmdd  \
# 20210917-TICK_xcme_sp_fut_0-eth    TICK  20210917
# 20210916-TICK_xcme_sp_fut_0-eth    TICK  20210916
# 20210915-TICK_xcbt_ff_fut_0-eth    TICK  20210915
# 20210914-TICK_xcbt_ff_fut_0-eth    TICK  20210914
# 20210913-TICK_xcbt_ff_fut_0-eth    TICK  20210913
#
#                                                                                url  \
# 20210917-TICK_xcme_sp_fut_0-eth  https://datamine.cmegroup.com/cme/api/v1/downl...
# 20210916-TICK_xcme_sp_fut_0-eth  https://datamine.cmegroup.com/cme/api/v1/downl...
# 20210915-TICK_xcbt_ff_fut_0-eth  https://datamine.cmegroup.com/cme/api/v1/downl...
# 20210914-TICK_xcbt_ff_fut_0-eth  https://datamine.cmegroup.com/cme/api/v1/downl...
# 20210913-TICK_xcbt_ff_fut_0-eth  https://datamine.cmegroup.com/cme/api/v1/downl...
#
#                                                              fid orderid  \
# 20210917-TICK_xcme_sp_fut_0-eth  20210917-TICK_xcme_sp_fut_0-eth   33513
# ...

# %%
dataCatalogDF.dataset.value_counts()
# Out:
# TICK    22499
# Name: dataset, dtype: int64

# %%
myDatamine.time_sales_load()
# Out:
# downloading TICK data:   0%|                                                         | 2/22499 [00:00<54:28,  6.88it/s]
# File Handling Area, looking for Content-Disposition Header and Lacks a 'header'...
# Expected a "filename" entry in the Content-Disposition header found:
#
# See log file for further detail.
# downloading TICK data:   0%|                                                        | 12/22499 [00:01<43:37,  8.59it/s]
# File Handling Area, looking for Content-Disposition Header and Lacks a 'header'...
# Expected a "filename" entry in the Content-Disposition header found:
#
# See log file for further detail.
# downloading TICK data:   0%|                                                        | 44/22499 [00:05<50:32,  7.40it/s]
# File Handling Area, looking for Content-Disposition Header and Lacks a 'header'...
# Expected a "filename" entry in the Content-Disposition header found:
#
# See log file for further detail.
# ...

# %%
ts = myDatamine.time_sales_DF

# %%
ts = ts.loc[ts['ticker_symbol'] == 'SP']

# %%
ts.to_csv(r"C:\Users\samas\data\TICK\spf_90.csv")

# %%
df = pd.read_csv(r"C:\Users\samas\OneDrive\Desktop\spf_90.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (17,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Out:
# array(['SP'], dtype=object)

# %%
# Out:
#           Unnamed: 0            trade_date_time                 trade_date  \
# 14856687    14856687  1991-10-30 08:30:02+00:00  1991-10-30 00:00:00+00:00
# 14856688    14856688  1991-10-30 08:30:06+00:00  1991-10-30 00:00:00+00:00
# 14856689    14856689  1991-10-30 08:30:06+00:00  1991-10-30 00:00:00+00:00
# 14856690    14856690  1991-10-30 08:30:12+00:00  1991-10-30 00:00:00+00:00
# 14856691    14856691  1991-10-30 08:30:17+00:00  1991-10-30 00:00:00+00:00
# ...              ...                        ...                        ...
# 34395866    34395866  2021-09-17 19:48:02+00:00  2021-09-17 00:00:00+00:00
# 34395867    34395867  2021-09-17 19:48:06+00:00  2021-09-17 00:00:00+00:00
# 34395868    34395868  2021-09-17 01:11:38+00:00  2021-09-17 00:00:00+00:00
# 34395869    34395869  2021-09-17 15:37:26+00:00  2021-09-17 00:00:00+00:00
# 34395870    34395870  2021-09-17 15:37:40+00:00  2021-09-17 00:00:00+00:00
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'trade_date_time', 'trade_date', 'trade_time',
#        'trade_sequence_number', 'session_indicator', 'ticker_symbol',
#        'future_option_index_indicator', 'contract_delivery_date',
#        'trade_quantity', 'strike_price', 'trade_price', 'ask_bid_type',
#        'indicative_quote_type', 'market_quote', 'close_open_type',
#        'valid_open_exception', 'post_close', 'cancel_code_type',
#        'insert_code_type', 'fast_late_indicator', 'cabinet_indicator',
#        'book_indicator', 'entry_date', 'exchange_code'],
#       dtype='object')
